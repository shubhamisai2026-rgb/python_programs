# %%
# Let's first define two numbers in a variable and print them and their type


no1=54
no2=45
print(no1+no2)
print(type(no1))
print(type(no1+no2))

# %%
# You can carry out basic + - * /
num1=45
num2=50
print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num2 / num1)   # division sometimes may result in float

print(no1+no2)
print(no1-no2)
print(no1*no2)
print(no1/no2)

# %%
# Other arithmatic operators - // % **


print(num2 // num1)  # this is called floor division i.e. the output is quotient without reminder i.e. discarding the numbers after decimal point
print(num2 % num1)   # this is called modulus i.e. the reminder after division
print(3 ** 2)        # exponent (^) ---> 3^2

print(no1//no2)
print(no1%no2)
print(no1**no2)

# %%
# Some more examples of floor division

print(9 // 3)
print(8 // 3)
print(7 // 3)
print(6 // 3)

print(5//6)
print(45//65)
print(43//45)
print(55//5)

# %%
# Some more examples of modulus

print(9 % 3)
print(8 % 3)
print(7 % 3)
print(6 % 3)

print(34%3)
print(54%3)
print(43%2)
print(43%32)

# %%
# Python supports BODMAS rule when multiple operators are in line

print(5 * 4 + 1)          # first multilpication will be executed
print(1 + 5 * 4)          # same as above first multilpication will be executed
print(5 * (4 + 1) )       # first brackets then rest

print(7+6*4)
print((45+54)*32)
print(((45+54)*4)+54)

# %%
# == checks whether left hand side and right hand side is equal

print(2 == 2)   # if LHS = RHS, output True else False
print(2 == 1)   # Here LHS is not equal to RHS

print(45==64)
print(45>32)

# %%
# Let's explore < > <= >=

print(3 != 2)

print(3 > 2)
print(3 < 2)

print(3 >= 3)
print(3 >= 2)

print(3 <= 2)
print()
print(3!=3)

print(45>65)
print(3>=3)
print(3>=2)
print(3<=2)

# %%
# += is a shortcut for add and assign

num = 4
print(num)

num += 1   # is equivalent to num = num + 1
print(num)

no1=54
print(no1)

no1+=54
print(no1)

no2+=65
print(no2)

# %%
# -= is a shortcut for subtract and assign

num = 4
print(num)

num -= 1   # is equivalent to num = num - 1
print(num)

no1-=54
print(no1)

# %%
num = 4
num *= 2
print(num)

no1*=3
print(no1)

# %%
num = 4
num /= 2
no1/=2
print(no1)
print(num)

# %%
# Three cases of AND

print(True and True)
print(True and False)   # same as False and True
print(False & False)    # instead of and, you can use &

# In short, if any one is false then answer is false
print()
print(True and True)
print(True and False)
print(False and True)
print(False and False)
print()
print(True * True)
print(True * False)
print(False * True)
print(False * False)
print()
print(True or True)
print(True or False)
print(False or True)
print(False or False)
print()

print(True + False)
print(False + True)
print(False + False)

# %%
# Three cases of OR

print(True or True)
print(True or False)
print(False | False)

# In short, if any one is true then answer is true
print(True & True)
print(True & False)
print(False & True)
print(False & False)
print()
print(True | True)
print(True | False)
print(False | True)
print(False | False)

# %%
# not is opposite of something (bool)

print(not True)
print(not False)
print(not(True and True))
print(not(False or False))

# %%
# AND needs both conditions to be True

x = 5
print(x > 4 and x < 6)

y=64
print(y>=54 and y<=76)

# %%
# OR evaluates for atleast one true condition

x = 5
print(x > 3 or x < 4)  # if any one condition is true, answer is true
y=78
print(y>43 or y<54)

# %%
# NOt operater checks for opposite result

x = 5
print(not(x > 3 and x < 10))
y=54
print(not(y>23 and y<84))

# %%
# abs() function gives positive number

print(abs(-2))
print(abs(-2.1))
print(abs(-43.54))
print(abs(-46))
print(abs(54.78))

# %%
# round() function rounds off the digits after decimal point

print(round(3.45))
print(round(-3.95))

print(round(56.35683))
print(round(-5.21))

# %%
# round() function with precision

print(round(3.46, 1))   # round the number till 1 decimal place
print(round(3.46, 2))   # round the number till 2 decimal place

print(round(3.469, 1))   # round the number till 1 decimal place
print(round(3.469, 2))   # round the number till 2 decimal place

print(round(43.2334,2))
print(round(46.5321,3))

# %%
# Just like integer, arithmatic operations can be applied on float

new1 = 2.1
new2 = 0.3

print(new1 + new2)
print(new1 - new2)

no1=34
no2=43.56

print(round(no1+no2))
print(no1+no2)
print(no1-no2)
print(round(no1-no2))

# %%
# Float and integer can be added to each other

fir = 3  # int
sec = 0.1  # float
print (fir + sec)

min=54
second=54.65
print(round(min+second))

# %%
# Funnily, if you add string and integer, you'll get a string

num1 = 'Hello'
num2 = '5'
print(num1 + num2)   # this is simply concatenation of strings
# Python is smart to figure out that one of the variable is string so the output results in string

no1='54'
name="shubham"
result=no1+name
print(result)

# %%
# Type casting  i.e. converting string to int

a = '2'
b = '3'
print(a, type(a))
print(b, type(b))
print('Addition = ', a+b)   # because this is string + string, the output will be simple concatenation of the digits i.e. output will be 23 instead of 5

print()                     # Leaves a blank space in output

a = int(a)
b = int(b)
print(a, type(a))       # here you'll get output as int
print(b, type(b))       # here you'll get output as int
print('Addition = ', a+b)

c=43
d=57.32
a=int(d)
print("addition=",c+a)

# %%
# But if you go about typecasting a proper string into int it'll give error
# THIS CELL WILL GIVE ERROR. IT IS MEANT FOR THAT. DON'T WORRY BECAUSE IT IS RED

a = 'hi'
a = int(a)    # this line will throw error (because python cannot convert 'hi' into  integer)
print(a)

# %%
# Float to str

num = 2.0
print(type(num))
num = str(num)
print(type(num))

name=43
print(type(name))
name=str(name)
print(type(name))

# %%
# str to bool

num = 'True'
print(type(num))
num = bool(num)
print(type(num))

name="False"
print(type(name))
name=bool(name)
print(type(name))

# %%
# Note, anything that you write in input() is accepted as string, even if it is an integer. Try passing some integer as input and check its datatype.

num = input('enter some integer  -  ')   # pass some number e.g. 2
print(num)
print(type(num))

no=input("enter your number:")
print(no)
print(type(no))

# %%
# To convert string into integer which is passed in input(), you can simply wrap it up in int() or float() class

num = input('Enter some number --- ')     # pass some number e.g. 2
print(num, type(num))
new = int(num)            # this is called typecasting (i.e. you are changing data type of variable) (this line will give you error if you pass some text in the input box, try it!)
print(new, type(new))

no1=input("enter your number:")
print(no1,type(no1))
new_no1=int(no1)
print(new_no1,type(new_no1))

# %%
# Carry addition of two user-inputted numbers

num1 = input('Enter first number:  ')
num2 = input('Enter second number:  ')
print(num1 + num2)    # this will simply append the two numbers one after the other
print(int(num1) + int(num2))   # this will actuall carry out the addition

no1=input("enter your first number:")
no2=input("enter your second number:")
print(no1+no2)
print(int(no1)+int(no2))

# %%
x = 4
y = 3
if x > y:             # if is followed by condition which is followed by :    # That's standard syntax
  print('yes, x is indeed greater than y')     # the main codeblock of if clause is denoted by leaving 4 indents (if there are less or more than 4 indents, it'll throw error)

  x=54
  y=89
  if y>x:
    print("y is greater than x")

# %%
x = 14
y = 15
if x > y:             # if is followed by condition which is followed by :    # That's standard syntax
  print('yes, x is indeed greater than y')
print('this statement is not part of if clause, hence there is no indent here')
x=59
y=86
if x>y:
  print("y is greater than x")
print("this statement is not the part of if condition")

# %%
x = 14
y = 13
if x > y:             # if is followed by condition which is followed by :    # That's standard syntax
  print('yes, x is indeed greater than y')
  print('I want to be part of if clause as well, so i have given 4 indents before print()')
print('this statement is not part of if clause, hence there is no indent here')

x=55
y=98
if y>x:
  print("y is a greater than x")
  print("this line is the part of a if condition")

print("this line is not a part of if condition")

# %%
# else statement lies on the same level as if
if 4 > 5:
    print('four is greater than five')
else:
    print('four is smaller than five')

    if 65>75:
        print("this is true")
    else:
        print("this is false")

# %%
# multiple if else => use elif

height = 176
if height < 140:
    print('too short')
elif height < 180:
    print('height is ok')
else:
    print('too tall')

age=34
if age>=18:
    print("you can vote")
elif age<=17:
    print("you can not b")

# %%
# You can pass boolean value (True or False) to the condition in if. In that case, you don't need any logical operator like == or !=


is_subscribed = False
if is_subscribed:              # Read it like - if True do THIS else do THAT
    print('Thank you for the subscription!')
else:
    print('Please subscribe')

is_installed=True
if is_installed:
    print("thans for installation")
else:
    print("please install first")

# %%
is_subscribed = True
if is_subscribed:
    print('Thank you for the subscription!')
else:
    print('Please subscribe')

is_installed=False
if is_installed:
    print("thanks for installation")
else:
    print("please install first")

# %%
x = 3
y = 4

if x < y and x + y > 5:
    print('both statements are true')

if x < y or x > y:
    print('one of the statement is true')

if x < y and not x + y < 5:
    print('both the statements must be true')

a=int(input("enter a first number:"))
b=int(input("enter a second number:"))
if a>b and a+b>70:
    print('both statement must true')
if b<a or a>b:
    print('one statement must be true')
if a<b and not a+b<70:
    print('both the statement must be true')

# %%
# Nested If

x = 7
if x > 10:
    print('x is greater than 10')
    if x > 20:
        print('x is greater than 20')
        if x > 30:
            print('x is greater than 30')
        else:
            print('x is smaller than 30')
    else:
        print('x is smaller than 20')
else:
    print('x is smaller than 10')

    print()

a=int(input("enter a number a :"))
if a>34:
    print("a is reater than a 34:")
    if a>75:
        print("a is greater than 75")
        if a>100:
            print("a is greater than 100")
        else:
            print("a is smaller than 100")
    else:
        print("a is smaller than 75")
else:
    print("a is smaller than 34")

# %%
# To find out if inputted number is within the range of 3 to 10
# if both conditions are True only then answer will be True else false

x = int(input("Enter any number within range 10: "))     # if you pass anything other than integer, it'll throw error. Because we are typecasting here itself
print(x >= 3 and x <= 10)

y=int(input("enter any number within range 100: "))
print(a>=30 and a<=100)
