# %%
# Use for loop to iterate through a list
courses = ['ba', 'bcom', 'bsc', 'be']

for course in courses:
    print(course)
print()
for item in courses:
    print(item)
print()
languages={"c","c++","java","python","typescript","dart","elixir","clojure","fsharp"}
for item in languages:
    print(item)
for id,item in enumerate(languages):
    print(id,item,len(item))

# %%
# Use for loop to iterate through a tuple
fruits = ('apple', 'banana', 'mango')

for fruit in fruits:
    print(fruit)
print()
name={"shubham","nagesh","myur","sachin","anurag","kiran"}
for item in name:
    print(item)

# %%
# Use for loop to iterate through a dictionary
company = {'name': 'Tesla', 'founder':'Elon', 'year': 2003}

for item in company:
    print(item, company[item])
print()
student={"roll_no":45,"name":"shubham","course":"msc(imca)","subject":"math"}
for item in student:
    print(item,student[item])

# %%
# Use for loop to iterate through a string
text = 'Hello'
for i in text:
  print(i)
print()
name="shubham isai"
for i  in name:
  print(i)

# %%
# range() comes handy when using for loop

for i in range(5):   # prints from 0 to 4
  print(i)

print('------------')

for i in range(3,8):   # prints from 3 to 7
  print(i)
print()
for i in range(11):
  print(i*i)
print()
for i in range(1,11):
  print(i*i*i)

# %%
# Use enumerator for getting index

courses = ['ba', 'bcom', 'bsc', 'be']
for id, item in enumerate(courses):
  print(id, item)
print()
cities=("pune","mumbai","nashik","kolhapur","solapur","satara","sangali","chh.sambhajinagar")
for id,item in enumerate(cities):
  print(id,item)

# %%
# If you want index, but don't want to use enumerate, there is another way

courses = ['ba', 'bcom', 'bsc', 'be']

for i in range(len(courses)):                # range(5) prints a list of numbers from 0 to 4. Here we are passing length of list to the range.
  print(i, courses[i])
print()
states=["maharashtra","keral","karnatak","tamilnadu","dilli","bangal"]
for i in range(len(states)):
  print(i,states[i])

# %%
# we can use condition inside for loop
courses = ['ba', 'bcom', 'bsc', 'be']

for course in courses:
    if course == 'bcom':
        print(course)
    else:
        print('Course is NOT bcom')
print()
subjects={"math","chemistry","physics","it"}
for item in subjects:
    if item=="math":
        print("subject are found:",item)
    else:
        print("subject are not found")

# %%
# exit a loop at a certain condition, say

courses = ['ba', 'bcom', 'bsc', 'be']
for item in courses:
  print(item)
  if item == 'bsc':                 # we wan't to break the loop when 'bsc' is reached
    break                           # 1. break is a special keyword that breaks through a loop  2. It is inside if statement, hence double identatition
print()
divisions={"marathwada","kokan","vidarbh","p_maharashtra"}
for item in divisions:
  print(item)
  
  if item=="kokan":
    break

# %%
# same as above, but let's print the values after if block. Just note the difference in output.

courses = ['ba', 'bcom', 'bsc', 'be']
for item in courses:
  if item == 'bsc':                 # we wan't to break the loop when 'bsc' is reached
    break                           # 1. break is a special keyword that breaks through a loop  2. It is inside if statement, hence double identatition
  print(item)                       # In this case we are printing the item after checking the condition
print()
languages=("c","c++","java","python","c#")
for item in languages:
  if item=="java":
    break
  print(item)

# %%
# if item is 'bsc', stop the current iteration but continue with the next

courses = ['ba', 'bcom', 'bsc', 'be']
for course in courses:
  if course == 'bsc':
    continue
  print(course)

names=["shubham","mayur","sharad","kiran","rohit","sachin","dinesh"]
for item in names:
  if item=="kiran":
    continue
  print(item)

# %%
courses=["ba","bcom","bsc","ma","mcom","msc"]
for id,item in enumerate(courses):
    print(id,item)

# %%
name = input('enter your name --- ')
print("let's print characeter separately")
for char in name:
  print(char)

think=input("enter your string:")
print("lets print character separatedly")
for char in think:
  print(char)

# %%
# Let's write a function that calculates square of each number
num = [1, 2, 3, 4, 5, 6, 7]

def sqr(item):
  return item * item

for i in num:
  print(i, sqr(i))
print()
def cube(item):
  return item*item*item

for i in range(10):
  print(i,cube(i))

# %%
# This gives the sum of the given list.

num = [10,30,23,43,65,12]
sum = 0
for i in num:
    sum = sum + i     # or we can write sum += i
print("The sum is:",sum)

number=(12,45,75,34,97,76,89,90)
sum=0
for i in number:
    sum=sum+i
print("the sum is:",sum)

# %%
# This gives multiplication table of number n given by user input

num = int(input("Enter the number "))
for i in range(1,11):
    c = num * i
    print(f"{num} x {i} ====> {c}")

number=int(input("enter the number "))
for i in range(1,11):
    c=number*i
    print(f'{number}*{i}',c)

# %%
# For loop inside for loop

adj = ["red", "big", "tasty"] #outer loop
fruits = ["apple", "banana", "cherry"] #inner loop

for x in adj:
  for y in fruits:
    print(x, y)

  names=("shubham","mayur","jayesh","nagesh","karan","pravin")
  subjects=("math","physics","chemmistry","biology","cs","it")
  for x in names:
    for y in subjects:
      print(x,y)

# %%
# NESTED loop

for i in range(4): # outer loop
    for j in range(20, 24): # inner loop
        print(i, j)
for i in range(1,11):
    for j in range(1,11):
        print(i*j)

# %%
# Prints a pattern using astrisk symbol

rows = int(input("Enter the rows  :"))    # e.g. 3
for i in range(0, rows+1):               # Outer loop will print number of rows   (+1 because range excludes the second number)
    for j in range(i):                   # Inner loop will print number of Astrisk
        print("*",'')               # print() can take different arguments, by default end='\n' i.e. new line
    print()                               # Once inner loop is finished, we want the control to come to the next line, hence blank print()

rows=int(input("enter the rows:"))
for i in range(0,rows+1):
    for j in range(i):
        print("*","")
    print()

# %%
""""
# Prints the number Pyramid

# User input for number of rows
rows = int(input("Enter the rows : "))
# Outer loop will print number of rows
for i in range(0,rows+1):
# Inner loop will print numbers
    for j in range(i):
        print(i, end = '')
    print()
"""
rows=6
for i in range (0,rows+1):
    for j in range(i):
        print(i,end="")
    print()
# Out:
# 1
# 22
# 333
# 4444
# 55555
# 666666

# %%
# How to check length of list if there was no len() function

nums = [11,23,30,43]
count = 0
for item in nums:
    count = count + 1
print("Total length - ",count)

names=["shubham","anurag","mayur","sachin","karan"]
count=0
for item in names:
    count=count+1
print("total length:",count)
# Out:
# Total length -  4
# total length: 5

# %%
# Check for some integer and print its index position using count identifier.
# Here we are trying to find position of 30

nums = [11,23,30,43]
count = 0
for item in nums:
    count = count + 1
    if item == 30:
        print("item matched")
        break
print("found at", count, "location")

names=["shubham","anurag","mayur","sachin","karan"]
count=0
for item in names:
    count=count+1
    if item=="mayur":
        print("item matched")
        break
print("found at",count,"location")
# Out:
# item matched
# found at 3 location
# item matched
# found at 3 location

# %%
# If letter is 'c' then say 'Found letter' else print the letter

letters = ['a', 'b', 'c', 'd', 'e']
for letter in letters:
    if letter == 'c':
        print('Found letter')
        break
    else:
        print(letter)
# Out:
# a
# b
# Found letter

# %%
names=["shubham","mayur","sachin","kiran","rohan","pravin","manisha"]
for name in names:
    if name=="sachin":
        print("found name")
        break
    else:
        print(name)
# Out:
# shubham
# mayur
# found name
