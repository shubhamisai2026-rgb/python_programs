# %%
# Let's define one tuple by putting some data in round brackets. Separate data must be separated by comma.

courses = ('ba', 'bcom', 'bsc')
print(courses)
print(type(courses))     # Note that we get class 'tuple' as output.

names=('shubham','mayur','nageshwar','anil','sachin','kiran','karan','pravin','gaurav','vaibhav')
print(names)
print(type(names))
# Out:
# ('ba', 'bcom', 'bsc')
# <class 'tuple'>
# ('shubham', 'mayur', 'nageshwar', 'anil', 'sachin', 'kiran', 'karan', 'pravin', 'gaurav', 'vaibhav')
# <class 'tuple'>

# %%
# To access data, just like list, simply pass index within []

print(courses[1])    # Index 1 = Position 2
print(names[2])
print(names[3])
print(names[0])
print(names[-1])
# Out:
# bcom
# nageshwar
# anil
# shubham
# vaibhav

# %%
# If you type courses. you'll get only two suggestions, meaning tuples has only two functions defined specifically for them. Let's explore them
# Check the last two entries when you run help()

help(tuple)
# Out:
# Help on class tuple in module builtins:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  count(self, value, /)
#  |      Return number of occurrences of value.
#  |
#  |  index(self, value, start=0, stop=9223372036854775807, /)
#  |      Return first index of value.
#  |
#  |      Raises ValueError if the value is not present.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
# count() - returns number of occurances of value
# Here 'ba' is used only once, hence output is 1

print(courses.count('ba'))
print(courses.count('baa'))    # 'baa' not part of courses. Output = 0
print(names.count("shubham"))
print(names.count("shubha"))
# Out:
# 1
# 0
# 1
# 0

# %%
#  index() - returns the first index of value
# bsc is defined at third position (second index)

print(courses.index('bsc'))
print(names.index("shubham"))
print(names.index("mayur"))
# Out:
# 2
# 0
# 1

# %%
# Let's re-define courses, and allow duplicate

courses = ('ba', 'bcom', 'bsc', 'bsc', 'ba')
print(courses)
print(courses.count('bsc'))            # 'bsc' is used twice hence 2
print(courses.index('bsc'))            # index returns the index of first occurance (so even if bsc is defined at index 2 and index 3, output will be 2)

subjects=("math","chemistry","cs","it","chemistry")
print(subjects)
print(subjects.count("chemistry"))
print(subjects.index("chemistry"))
# Out:
# ('ba', 'bcom', 'bsc', 'bsc', 'ba')
# 2
# 2
# ('math', 'chemistry', 'cs', 'it', 'chemistry')
# 2
# 1

# %%
# As we saw in the list, whenever there is collection of data, for loop becomes important.
# Let's see simple example of for loop

for item in courses:
  print(item)
for item in subjects:
  print(item)
for item in names:
  print(item)
# Out:
# ba
# bcom
# bsc
# bsc
# ba
# math
# chemistry
# cs
# it
# chemistry
# shubham
# mayur
# nageshwar
# anil
# sachin
# kiran
# karan
# pravin
# gaurav
# vaibhav

# %%
# Use enumerate() function to get index of element as well

for id, item in enumerate(courses):    # enumerate() returns index along with main data. Hence you need two variables at the left (id, item). These names could be any.
  print(id, item)
for id,item in enumerate(subjects):
  print(id,item)
for id,item in enumerate(names):
  print(id,item)
# Out:
# 0 ba
# 1 bcom
# 2 bsc
# 3 bsc
# 4 ba
# 0 math
# 1 chemistry
# 2 cs
# 3 it
# 4 chemistry
# 0 shubham
# 1 mayur
# 2 nageshwar
# 3 anil
# 4 sachin
# 5 kiran
# 6 karan
# 7 pravin
# 8 gaurav
# 9 vaibhav

# %%
# Check length of the tuple
# len() comes handy. This function can be used over str, list, tuple and few more..

print(len(courses))
print(len(subjects))
print(len(names))
# Out:
# 5
# 5
# 10

# %%
# If you are storing numbers in tuple, you don't need ''

nums = (2, 3, 4)
print(type(nums))

print(type(names))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
# Mix of str and int and bool is allowed in tuple

data = ('ba', 2, True, 'bsc')
print(data)
print(type(data))

data2=("bcom",43,False,54.65)
print(data2)
print(type(data2))
# Out:
# ('ba', 2, True, 'bsc')
# <class 'tuple'>
# ('bcom', 43, False, 54.65)
# <class 'tuple'>

# %%
# For the sake of it, let's check data type of each of the object

print(type(data[0]))
print(type(data[1]))
print(type(data[2]))
print(type(data2[0]))
print(type(data2[1]))
print(type(data2[2]))
print(type(data2[3]))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>

# %%
# Let's do the same with for loop
for item in data:
  print(item, type(item))

for item in data2:
  print(item,type(item))
# Out:
# ba <class 'str'>
# 2 <class 'int'>
# True <class 'bool'>
# bsc <class 'str'>
# bcom <class 'str'>
# 43 <class 'int'>
# False <class 'bool'>
# 54.65 <class 'float'>

# %%
# TRICKY ONE. For single valued tuple, you have to add a comma, else it'll be treated as a string

new = ('50')              # this will be treated as string
print(type(new))

print('-----------------------------')

new1 = ('50',)            # this will be treated as tuple
print(type(new1))

a=(2)
b=(2,)
print(type(a))
print(type(b))
# Out:
# <class 'str'>
# -----------------------------
# <class 'tuple'>
# <class 'int'>
# <class 'tuple'>

# %% [markdown]
# **Concat two tuples**

# %%
# simply use + to combine two tuples into one

print(('a','b','c') + (1, 2, 3))
print(("shubham","mayur","nageshwar")+(1,2,3))
print(f'{(1,2,3)},{("shubham","mayur")}')
# Out:
# ('a', 'b', 'c', 1, 2, 3)
# ('shubham', 'mayur', 'nageshwar', 1, 2, 3)
# (1, 2, 3),('shubham', 'mayur')

# %%
# More than two tuples can also be added the same way

new = ('50',)
new1 = ('apple',)
new2 = ('mango','orange')
print(new + new1 + new2)

a=('60',)
b=("apple",)
c=("banana","grapes","mango")
print(a+b+c)
# Out:
# ('50', 'apple', 'mango', 'orange')
# ('60', 'apple', 'banana', 'grapes', 'mango')

# %%
# To delete, use del
del new2
# print(new2)    # This will give error because new2 is not defined any more, it's deleted already
del a
del b
del c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # To delete, use del
# ----> 2 del new2
#       3 # print(new2)    # This will give error because new2 is not defined any more, it's deleted already
#       4 del a
#
# NameError: name 'new2' is not defined

# %%
# check whether an element is in the tuple

fruits = ('apple','mango')

print('mango' in fruits)     # return True if 'mango' is part of fruits else False. Thanks to 'IN', it comes handy many times in the real world programs.
print('mangoes' in fruits)

print("shubham" in names)
print("mayur" in names)
print("anl" in names)
# Out:
# True
# False
# True
# True
# False

# %%
#  Algebraic operations like max, min etc

print(max(2, 1, 3, 7))
print(min(2, 1, 3, 7))
print(max(names))
print(max(subjects))
print(min(names))
print(min(subjects))
# Out:
# 7
# 1
# vaibhav
# math
# anil
# chemistry

# %%
# To convert list into a tuple
num = [1, 2, 3, 4]
new = tuple(num)

print(num)
print(new)

names2=list(names)
print(names2)
 
subjects2=list(subjects)
print(subjects2)
# Out:
# [1, 2, 3, 4]
# (1, 2, 3, 4)
# ['shubham', 'mayur', 'nageshwar', 'anil', 'sachin', 'kiran', 'karan', 'pravin', 'gaurav', 'vaibhav']
# ['math', 'chemistry', 'cs', 'it', 'chemistry']

# %% [markdown]
# ### Playing with indexes

# %%
# Just like list, you can use -1 to get the last element, and -2 to get second last element

num = (1, 2, 3, 4, 5, 6, 7)
print(num[-1])
print(num[-2])

print(names[-1])
print(names[-2])
# Out:
# 7
# 6
# vaibhav
# gaurav

# %%
# num has 7 elements i.e. indexes from 0 to 6. So 7th index will give error

print(num[6])   # = 7
# print(num[7])   # should give error
print(names[9])
# Out:
# 7
# vaibhav

# %%
courses = ('ba', 'bcom', 'bsc', 'be', 'ma', 'mcom',' msc', 'me')
print(courses[3:5])   # print courses from 3rd index to 5th
print(courses[3:])   # print courses from 3rd index onwards
print(courses[:3])   # print courses upto 3d index

print(names[1:5])
print(names[3:6])
print(names[:6])
print(names[3:])
# Out:
# ('be', 'ma')
# ('be', 'ma', 'mcom', ' msc', 'me')
# ('ba', 'bcom', 'bsc')
# ('mayur', 'nageshwar', 'anil', 'sachin')
# ('anil', 'sachin', 'kiran')
# ('shubham', 'mayur', 'nageshwar', 'anil', 'sachin', 'kiran')

# %%
print(courses[-3:])   # print last three courses
print(names[-3:])
print(names[-4:])
# Out:
# ('mcom', ' msc', 'me')
# ('pravin', 'gaurav', 'vaibhav')
# ('karan', 'pravin', 'gaurav', 'vaibhav')
